# %% [markdown]
# <a href="https://colab.research.google.com/github/PalomiBollapalli/PnS-LAB/blob/main/LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Titanic dataset
file_path = "titanic.csv"  # Ensure the file is in the same directory

df = pd.read_csv("titanic.csv")

# Standardize column names
df.rename(columns={
    "Passenger ID": "PassengerID",
    "Gender": "Sex",
    "Class": "Pclass",
    "Siblings/Spouses Aboard": "SibSp",
    "Parents/Children Aboard": "Parch"
}, inplace=True)

df["Pclass"] = df["Pclass"].map({"1st": 1, "2nd": 2, "3rd": 3})

sns.set_style("whitegrid")

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], bins=15, kde=True, color='skyblue')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Distribution of Passenger Ages")
plt.axvline(df['Age'].median(), color='red', linestyle='dashed', label='Median Age')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived', alpha=0.7, palette={0: 'red', 1: 'green'})
plt.xlabel("Age")
plt.ylabel("Fare Paid")
plt.title("Fare vs. Age with Survival Status")
sns.regplot(data=df, x='Age', y='Fare', scatter=False, color='black')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Pclass', palette="pastel")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.title("Passenger Count by Class")
plt.show()
# Out:
# <ipython-input-60-9ec855fa333d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Pclass', palette="pastel")

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Pclass', hue='Survived', palette={0: 'red', 1: 'green'})
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Survival Count by Passenger Class")
plt.legend(title="Survived", labels=["No", "Yes"])
plt.show()
